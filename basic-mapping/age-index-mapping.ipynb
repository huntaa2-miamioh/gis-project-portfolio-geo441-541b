# %% [markdown]
# <a href="https://colab.research.google.com/github/huntaa2-miamioh/gis-project-portfolio-geo441-541b/blob/main/basic-mapping/age-index-mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Querying Vector Data Tables**

# %% [markdown]
# Created by Ava Hunt
#
# 10/1/2025

# %% [markdown]
# ##**Part 1: Oldsters Map**

# %% [markdown]
# Below is a map of high age-index U.S. counties prepared following the Week 5 Assignment Guide.
#
# ```markdown
# [https://drive.google.com/file/d/1AizHaSdioOLVPLSKaEHA35NPECUE96xK/view?usp=sharing]
# ```
#
# Create a viewable link of the map
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1AizHaSdioOLVPLSKaEHA35NPECUE96xK]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![oldsters map](https://drive.google.com/uc?export=view&id=1AizHaSdioOLVPLSKaEHA35NPECUE96xK)
# ```
# ![oldsters map](https://drive.google.com/uc?export=view&id=1AizHaSdioOLVPLSKaEHA35NPECUE96xK)

# %% [markdown]
# ##**Part 2: Table Join**

# %% [markdown]
# Below is a screenshot of selected records in a joined table prepared following the Week 5 Assignment Guide.
#
#
# ```markdown
# [https://drive.google.com/file/d/1bxLYJewtUgkQelrjYurweSMdmVOnHIy7/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1bxLYJewtUgkQelrjYurweSMdmVOnHIy7]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![selected records](https://drive.google.com/uc?export=view&id=1bxLYJewtUgkQelrjYurweSMdmVOnHIy7)
# ```
#
# ![selected records](https://drive.google.com/uc?export=view&id=1bxLYJewtUgkQelrjYurweSMdmVOnHIy7)

# %% [markdown]
# ##**Part 3: Soil Fertility Map**

# %% [markdown]
# Below is a map of soil fertility prepared following the Week 5 Assignment Guide.
#
# ```markdown
# [https://drive.google.com/file/d/17Vzh_KgpG2HJxPtlp91ou2uJXGJXDpDs/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=17Vzh_KgpG2HJxPtlp91ou2uJXGJXDpDs]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![soil fertility map](https://drive.google.com/uc?export=view&id=17Vzh_KgpG2HJxPtlp91ou2uJXGJXDpDs)
# ```
#
# ![soil fertility map](https://drive.google.com/uc?export=view&id=17Vzh_KgpG2HJxPtlp91ou2uJXGJXDpDs)

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link. <mark>**Submit the shareable link to Canvas for the Week 5 Assignment.**</mark>

# %% [markdown]
# ## **References**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
