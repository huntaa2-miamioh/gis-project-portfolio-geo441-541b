# %% [markdown]
# <a href="https://colab.research.google.com/github/huntaa2-miamioh/gis-project-portfolio-geo441-541b/blob/main/basic-mapping/first-arcgis-mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# **This is bold text**
# *This is italic text*
#
# - Item 1
#   - Item 1.1
# - Item 2
# - Item 3
# - Item 4
#
# 1. First item
# 2. Second Item
# 3. Third Item
#
# [Google Colab](https://colab.research.google.com)
#
# ![google logo](https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png)
#
# ```python
# print("Hello, World!")
# ```
#
# > This is a blockquote.

# %% [markdown]
# ![commute](https://drive.google.com/uc?export=view&id=14ZkDDN6esG_65Qgi7w5er2Np9appP5NZ)
