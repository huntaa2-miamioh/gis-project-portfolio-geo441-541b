# %% [markdown]
# <a href="https://colab.research.google.com/github/huntaa2-miamioh/gis-project-portfolio-geo441-541b/blob/main/spatial-data-analysis/census-data-ohio-california.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Census Data**

# %% [markdown]
# Created by Ava Hunt
#
# 11/22/2025

# %% [markdown]
# ## **1. Smartphone Use in Ohio, 2023**
#
# ---

# %% [markdown]
# Below is a map of smartphone use in Ohio using data from the 2023 American Community Survey (5-Year Estimates).
#
#
# ![smartphone](https://drive.google.com/uc?export=view&id=1UspywnTObU0IlddmtxhgueHy89b-8fFa)

# %% [markdown]
# ### **2. Final Project Draft Map**

# %% [markdown]
# Below is a draft map of a final project map.
#
#
# ![ 2019 Map draft](https://drive.google.com/uc?export=view&id=1JHLWYPiKeeDIaacwjAHaAVxgZMfVwqv6)
#
# ![ 2021 Draft Map](https://drive.google.com/uc?export=view&id=1vPSud6Y0uSCFIoTekzoUuzF_jPP-lNM_)
#
# ![ 2023 draft map](https://drive.google.com/uc?export=view&id=1eBC9UFOprylyH5J3Wd2LYDfcWbXwoN3W)

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 12 & 13 Assignment.**</mark>
