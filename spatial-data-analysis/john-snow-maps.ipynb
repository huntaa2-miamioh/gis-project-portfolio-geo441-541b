# %% [markdown]
# <a href="https://colab.research.google.com/github/huntaa2-miamioh/gis-project-portfolio-geo441-541b/blob/main/spatial-data-analysis/john-snow-maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Vector Data / Spatial Analysis**

# %% [markdown]
# Created by Ava Hunt
#
# 11/5/2025

# %% [markdown]
# ## **Part 1: John Snow Cholera Maps**
#
# ---

# %% [markdown]
# ### **1a: Water Pump Buffer Map**

# %% [markdown]
# Below is a map of cholera deaths inside a 100m buffer of water pumps in the Soho District of London, 1854.
#
# ```markdown
# [https://drive.google.com/file/d/1cQhkpB6E3Dsgbzx15-j3SGG5aqX33htd/view?usp=sharing]
# ```
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1cQhkpB6E3Dsgbzx15-j3SGG5aqX33htd]
# ```
#
#
# ![pump buffer](https://drive.google.com/uc?export=view&id=1cQhkpB6E3Dsgbzx15-j3SGG5aqX33htd)

# %% [markdown]
# ### **1b: Cholera Deaths Heatmap**

# %% [markdown]
# Below is a heatmap of cholera deaths in the Soho District of London, 1854.
#
# ```markdown
# [https://drive.google.com/file/d/1YDv8fDot-UkU30MdQGOX8JS8VjKR3K_-/view?usp=sharing]
# ```
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1YDv8fDot-UkU30MdQGOX8JS8VjKR3K_-]
# ```
#
#
#
# ![heatmap](https://drive.google.com/uc?export=view&id=1YDv8fDot-UkU30MdQGOX8JS8VjKR3K_-)

# %% [markdown]
# ## **Part 2: Campgrounds**
#
# ---

# %% [markdown]
# Below is a map of sites suitable for campgrounds on private land near Hugo Lake, MN.
#
# ```markdown
# [https://drive.google.com/file/d/1RurKk_pztKIhT-OfDgrFw4TR8bhkMakA/view?usp=sharing]
# ```
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1RurKk_pztKIhT-OfDgrFw4TR8bhkMakA]
# ```
#
#
#
# ![private land](https://drive.google.com/uc?export=view&id=1RurKk_pztKIhT-OfDgrFw4TR8bhkMakA)

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 10 Assignment.**</mark>
